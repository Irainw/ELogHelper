# %%
from wikiScrape import WikiScraper

# %%
url = 'https://aosd.slac.stanford.edu/wiki/index.php/BSOICs'

# %%
url = 'https://aosd.slac.stanford.edu/wiki/index.php/BSOICs'
scraper = WikiScraper('https://aosd.slac.stanford.edu/wiki/index.php/')
title, text, soup = scraper.articleData(url)
print(text)
# Out:
# From MCC Wiki Jump to navigation Jump to search Overview Beam Shutoff Ion Chambers (BSOICs) are used at the SPEAR3 injector, storage ring, and beamline experimental areas.  Their purpose is to detect radiation outside the housing and shut off the beam if a preset radiation level is reached (e.g., 7mR/hr). The number of BSOICs, as well as placement and trip level, is specified by the associated Beam Authorization Sheet (BAS). BSOIC trips do not dump stored beam, they block injection. For SPEAR, booster, and beamline BSOICs, this is done by putting in the LTB stoppers and shutting off the LTB B1 magnet power supply. For linac BSOICs, the modulator drive and triggers are removed. As with most SPEAR injection interlocks nowadays, for any BSOIC trip the chopper is also briefly disabled to turn it off if it happens to be on. All BSOIC maintenance, calibration, testing, repair, and replacement is now taken care of by the RP (Radiation Physics) department. If there is a BSOIC problem, SPEAR 
# ...
