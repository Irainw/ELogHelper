# %%
import numpy as np
from bs4 import BeautifulSoup
import requests
import re
import random
from datetime import datetime
import matplotlib.pyplot as plt

# %%
def scrapeArticle(url):
	response = requests.get(url)
	soup = BeautifulSoup(response.content, 'html.parser')
	
	title = soup.find(id='firstHeading').text
	#print(title)
	text = soup.find(id='bodyContent').text
	
	links = soup.find(id='bodyContent').find_all('a')
	#print(links)
	scrapedLinks = [a for a in links if a['href'].startswith('/wiki/index.php')]
	if len(scrapedLinks)==0:
		print('no links scraped')
	else:
		randomLink = random.choice(scrapedLinks)
		scrapeArticle('https://aosd.slac.stanford.edu/' + randomLink['href'])

# %%
response = requests.get("https://aosd.slac.stanford.edu/wiki/index.php/Training")
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup.prettify())

list(soup.children)
links = soup.find(id = 'bodyContent').find_all('a')
hrefLink = [a for a in links if a['href'].startswith('/wiki/')]
print(f'Links are {links} and hrefLinks are {hrefLink}')
	
	
#scrapeArticle('https://aosd.slac.stanford.edu/wiki/index.php/Category:ASO1')
#scrapeArticle('https://aosd.slac.stanford.edu/wiki/index.php/Gotchas')
# Out:
# Links are [<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>, <a class="mw-jump-link" href="#searchInput">Jump to search</a>, <a href="/wiki/index.php/Category:Training" title="Category:Training">Category:Training</a>, <a class="external text" href="https://docs.google.com/spreadsheets/d/1gXVa5g4RH80tUKXTkzxKciEY-URasuImgnUaBg_cpv0/edit#gid=1497408858" rel="nofollow">here</a>, <a href="#Operator_Introductions"><span class="tocnumber">1</span> <span class="toctext">Operator Introductions</span></a>, <a href="#Accelerator_Physics_Fundamentals"><span class="tocnumber">2</span> <span class="toctext">Accelerator Physics Fundamentals</span></a>, <a href="#New_Operator_Training"><span class="tocnumber">3</span> <span class="toctext">New Operator Training</span></a>, <a href="#ASO-1_LAF_Training"><span class="tocnumber">4</span> <span class="toctext">ASO-1 LAF Training</span></a>, <a href="#ASO-1_SPEAR_Training"><span class="tocnumber">5</span> <span class="toctext">ASO-1 SPEAR Training</span></a>, <a href="#ASO-2_Training"><span class="tocnumber">6</span> <span class="toctext">ASO-2 Training</span></a>, <a href="#SPEAR_OIC_Qualification"><span class="tocnumber">7</span> <span class="toctext">SPEAR OIC Qualification</span></a>, <a href="#Accelerator_Operator_Training_Resources"><span class="tocnumber">8</span> <span class="toctext">Accelerator Operator Training Resources</span></a>, <a href="#PPS_Training"><span class="tocnumber">8.1</span> <span class="toctext">PPS Training</span></a>, <a href="#Miscellaneous"><span class="tocnumber">8.2</span> <span class="toctext">Miscellaneous</span></a>, <a href="#Other_Resources"><span class="tocnumber">9</span> <span class="toctext">Other Resources</span></a>, <a href="#Math_&amp;_Physics_&amp;_Engineering_Stuff"><span class="tocnumber">9.1</span> <span class="toctext">Math &amp; Physics &amp; Engineering Stuff</span></a>, <a href="#Controls"><span class="tocnumber">9.2</span> <span class="toctext">Controls</span></a>, <a href="#Hardware"><span class="tocnumber">9.3</span> <span class="toctext">Hardware</span></a>, <a href="#Software"><span class="tocnumber">9.4</span> <span class="toctext">Software</span></a>, <a href="#Talks"><span class="tocnumber">9.5</span> <span class="toctext">Talks</span></a>, <a href="#USPAS_Courses"><span class="tocnumber">9.6</span> <span class="toctext">USPAS Courses</span></a>, <a href="#Other_National_Laboratories"><span class="tocnumber">9.7</span> <span class="toctext">Other National Laboratories</span></a>, <a href="#Machine_Learning_Projects"><span class="tocnumber">9.8</span> <span class="toctext">Machine Learning Projects</span></a>, <a href="#Misc"><span class="tocnumber">9.9</span> <span class="toctext">Misc</span></a>, <a href="/wiki/index.php/Accelerator_Introduction" title="Accelerator Introduction">Accelerator Introduction</a>, <a href="/wiki/index.php/Magnets_Introduction" title="Magnets Introduction">Magnets Introduction</a>, <a href="/wiki/index.php/RF_Introduction" title="RF Introduction">RF Introduction</a>, <a href="/wiki/index.php/Energy_and_Momentum" title="Energy and Momentum">Energy and Momentum</a>, <a href="/wiki/index.php/Transverse_Linear_Motion" title="Transverse Linear Motion">Transverse Linear Motion</a>, <a href="/wiki/index.php/Phase_Space_and_Emittance" title="Phase Space and Emittance">Phase Space and Emittance</a>, <a href="/wiki/index.php/Acceleration_and_Phase_Stability" title="Acceleration and Phase Stability">Acceleration and Phase Stability</a>, <a href="/wiki/index.php/Synchrotron_Radiation" title="Synchrotron Radiation">Synchrotron Radiation</a>, <a href="/wiki/index.php/FEL_Introduction" title="FEL Introduction">FEL Introduction</a>, <a class="external text" href="https://slac.sharepoint.com/:b:/r/sites/pub/Publications/New%20Employee%20Orientation%20Workbook.pdf?csf=1&amp;web=1&amp;e=g6mlPi" rel="nofollow"><i>New Employee Orientation Workbook</i></a>, <a href="/wiki/index.php/New_Operator_Reference_Manual" ti ...
